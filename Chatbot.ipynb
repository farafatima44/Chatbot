# %%
import os
import openai
openai.api_key=os.getenv("sk-Il0pvVLqDX0wHWETlwKHzg1tkI4x5wTIpGUu4uDh-fT3BlbkFJ05BZhz6XUP3F72ETwYenWrLon0ZTdPIrs_ARxY5RoA")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 import openai
#       3 openai.api_key=os.getenv("sk-Il0pvVLqDX0wHWETlwKHzg1tkI4x5wTIpGUu4uDh-fT3BlbkFJ05BZhz6XUP3F72ETwYenWrLon0ZTdPIrs_ARxY5RoA")
#
# ModuleNotFoundError: No module named 'openai'

# %%
# !pip install openai
# Out:
# ...
#   Using cached openai-1.43.0-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached jiter-0.5.0-cp312-none-win_amd64.whl.metadata (3.7 kB)
# ...
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# ...
# Using cached openai-1.43.0-py3-none-any.whl (365 kB)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached jiter-0.5.0-cp312-none-win_amd64.whl (189 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# ...

# %%
import openai

# %%
import openai

# Set your API key here
openai.api_key = ' sk-Il0pvVLqDX0wHWETlwKHzg1tkI4x5wTIpGUu4uDh-fT3BlbkFJ05BZhz6XUP3F72ETwYenWrLon0ZTdPIrs_ARxY5RoA'

# %%
import openai
import os

# Retrieve API key from environment variable
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
import openai
import os

# Retrieve API key from environment variable
openai.api_key = os.getenv(' sk-Il0pvVLqDX0wHWETlwKHzg1tkI4x5wTIpGUu4uDh-fT3BlbkFJ05BZhz6XUP3F72ETwYenWrLon0ZTdPIrs_ARxY5RoA')

# %%
import panel as pn

# Ensure Panel extension is loaded
pn.extension()

# Define your context with personalized greeting
context = """
Your name is BariGPT, a personal data structures tutor with the personality of Abdul Bari. 
You first say hi to your student by name, Fara Fatima, then ask them what they want to learn.
You then tell them to input any of the following:

Arrays OF TWO NUMBERS TOPIC
Stack TOPIC
Explain TOPIC

When Fara Fatima writes "Arrays OF TWO NUMBERS", provide a good introduction for beginners, examples, diagrams, and explanation with example models. Break down into points, easy to read and understand, and provide the uses of it.
When Fara Fatima writes "Stack TOPIC", provide a good introduction for beginners, examples, diagrams, and explanation with example models. Break down into points, easy to read and understand, and provide the uses of it.
When Fara Fatima writes "Explain TOPIC", provide a good introduction for beginners, examples, diagrams, and explanation with example models. Break down into points, easy to read and understand, and provide the uses of it.

For what I ask you to do, determine the underlying problem I am trying to solve and how I am trying to solve it. List at least two alternative approaches to solve the problem and compare and contrast the approach with the approach implied by my request to you.
Ask me for the first task.
CAPS LOCK words are placeholders for content inputted by the user. Content enclosed in "double quotes" indicates what the user types in. The user can end the current command anytime by typing "menu" and you tell them to input any of the following:

Arrays OF TWO NUMBERS TOPIC
Stack TOPIC
Explain TOPIC
"""

# Define a function to handle user input and generate responses
def handle_input(input_text):
    if "Arrays OF TWO NUMBERS" in input_text:
        response = (
            "Hello Fara Fatima, this is BariGPT, your personal data structures tutor! "
            "Arrays are a fundamental data structure in programming. They store a collection of items in a single variable. For example, an array of two numbers could be [1, 2]. Here’s how you can use arrays in programming:\n\n"
            "1. **Definition**: Arrays store data in a contiguous block of memory.\n"
            "2. **Access**: Items are accessed using an index.\n"
            "3. **Examples**:\n"
            "   - `arr = [1, 2]`\n"
            "   - **Diagram**: Imagine an array as a row of boxes where each box holds a value.\n"
            "4. **Uses**: Arrays are used for storing collections of data, performing computations, etc.\n\n"
            "Example Model:\n```python\narr = [1, 2]\nprint(arr[0]) # Output: 1\n```"
        )
    elif "Stack TOPIC" in input_text:
        response = (
            "Hello Fara Fatima, this is BariGPT, your personal data structures tutor! "
            "A stack is a linear data structure that follows the Last In First Out (LIFO) principle. Elements are added to the top and removed from the top.\n\n"
            "1. **Definition**: Stacks operate on the principle of 'last in, first out'.\n"
            "2. **Operations**:\n"
            "   - **Push**: Add an item to the top.\n"
            "   - **Pop**: Remove the item from the top.\n"
            "3. **Examples**:\n"
            "   - **Diagram**: Think of a stack of plates; you add and remove plates from the top.\n"
            "4. **Uses**: Stacks are used in function calls, undo mechanisms in software, etc.\n\n"
            "Example Model:\n```python\nstack = []\nstack.append(1) # Push 1\nstack.append(2) # Push 2\nprint(stack.pop()) # Output: 2\n```"
        )
    elif "Explain TOPIC" in input_text:
        response = (
            "Hello Fara Fatima, this is BariGPT. Please specify the topic you want explained. "
            "Here are the topics you can choose from:\n\n"
            "1. **Arrays OF TWO NUMBERS**: Explanation about arrays with examples and diagrams.\n"
            "2. **Stack TOPIC**: Explanation about stacks with examples and diagrams.\n"
            "3. **Any other topic**: Provide a detailed explanation and examples.\n\n"
            "Type the topic you want to learn about or 'menu' to return to the menu."
        )
    elif "menu" in input_text:
        response = (
            "Hello Fara Fatima, this is BariGPT. Please input one of the following topics:\n\n"
            "Arrays OF TWO NUMBERS TOPIC\n"
            "Stack TOPIC\n"
            "Explain TOPIC"
        )
    else:
        response = (
            "Sorry, I didn’t understand that. Please type one of the following:\n\n"
            "Arrays OF TWO NUMBERS TOPIC\n"
            "Stack TOPIC\n"
            "Explain TOPIC\n"
            "Or type 'menu' to return to the menu."
        )

    return response

# Define the function to handle button clicks
def collect_messages(event):
    user_input = inp.value
    response_text = handle_input(user_input)
    return pn.pane.Markdown(response_text, width=1000)

# Create the widgets
inp = pn.widgets.TextInput(value='Hi', placeholder='What do you want to learn today?', width=500)
button_conversation = pn.widgets.Button(name="Start Learning!", width=200)

# Bind the function to the button click
interactive_conversation = pn.bind(collect_messages, button_conversation)

# Create the dashboard
dashboard = pn.Column(
    inp,
    button_conversation,
    pn.panel(interactive_conversation, loading_indicator=True, width=1000)
)

# Display the dashboard
dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='c4a3f613-cae8-4c4c-9685-c99a8619de51'>
#   <div id="aca34e43-14a9-4d5d-a0b5-509608f4df80" data-root-id="c4a3f613-cae8-4c4c-9685-c99a8619de51" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
